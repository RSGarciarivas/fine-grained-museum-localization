# %% [markdown]
# # Build a dictionary containing SIFT keypoints and descriptors for each image in the training set, save it as .pkl file

# %% [markdown]
# ### Necessary imports

# %%
import glob
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
import pickle

# %% [markdown]
# ### Build SIFT features dictionary

# %%
# Get list of all images
img_paths = glob.glob('./Dataset/train/*')

print(f'{len(img_paths)} images to analyse.')

# Dictionary for storing features for each image
SIFT_features = {}

# Work on each image
for i, img_path in enumerate(img_paths):
      
    print(f'Working on image {i + 1} of {len(img_paths)}')
    
    # Read image
    img = cv.imread(img_path)
    
    # Obtain SIFT keypoints and descriptors
    sift = cv.SIFT_create()
    kp, des = sift.detectAndCompute(img, None)
    
    # List for storing all keypoints' data
    keypoints = []
    
    for keypoint in kp:
        # Extract keypoint info in a way that can be stored in a file
        keypoint = {'pt': keypoint.pt, 'size': keypoint.size, 'angle': keypoint.angle,
                    'response': keypoint.response, 'octave': keypoint.octave,
                    'class_id': keypoint.class_id}
        
        keypoints.append(keypoint)
    
    # Append them in dictionary
    SIFT_features[img_path[16:-4]] = {'keypoints': keypoints, 'descriptors': des}
# Out:
# 7500 images to analyse.
# Working on image 1 of 7500
# Working on image 2 of 7500
# Working on image 3 of 7500
# Working on image 4 of 7500
# Working on image 5 of 7500
# Working on image 6 of 7500
# Working on image 7 of 7500
# Working on image 8 of 7500
# Working on image 9 of 7500
# Working on image 10 of 7500
# Working on image 11 of 7500
# Working on image 12 of 7500
# Working on image 13 of 7500
# Working on image 14 of 7500
# Working on image 15 of 7500
# Working on image 16 of 7500
# Working on image 17 of 7500
# Working on image 18 of 7500
# Working on image 19 of 7500
# Working on image 20 of 7500
# Working on image 21 of 7500
# Working on image 22 of 7500
# Working on image 23 of 7500
# Working on image 24 of 7500
# Working on image 25 of 7500
# Working on image 26 of 7500
# Working on image 27 of 7500
# Working on image 28 of 7500
# Working on image 29 of 7500
# Working on image 30 of 7500
# Working on image 31 of 7500
# Working on image 32 of 7500
# ...

# %% [markdown]
# ### Visualise random image with features

# %%
# Display random image
i = np.random.randint(0, len(SIFT_features))
img_path = img_paths[i]

# Load image
img = cv.cvtColor(cv.imread(img_path), cv.COLOR_BGR2RGB)
img_name = img_path[16:-4]

# Load keypoints and descriptors

# List for storing keypoint objects
kp = []

# Extract data for each keypoint from the image
for keypoint in SIFT_features[img_name]['keypoints']:
    point = keypoint['pt']
    size = keypoint['size']
    angle = keypoint['angle']
    response = keypoint['response']
    octave = keypoint['octave']
    class_id = keypoint['class_id']
    
    # Build keypoint object
    feature = cv.KeyPoint(x = point[0], y = point[1], _size = size, _angle = angle,
                         _response = response, _octave = octave, _class_id = class_id)
    
    # Append to keypoint list
    kp.append(feature)

des = SIFT_features[img_name]['descriptors']

# Draw features on image
kp_img = cv.drawKeypoints(img, kp, None, flags = cv.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

# Plot
plt.subplots(figsize = (15, 15))
plt.imshow(kp_img)
plt.axis('off')
plt.show()

# %% [markdown]
# ### Save dataset of features in a JSON file

# %%
with open('SIFT_features.pkl', 'wb') as output_file:
    pickle.dump(SIFT_features, output_file)
