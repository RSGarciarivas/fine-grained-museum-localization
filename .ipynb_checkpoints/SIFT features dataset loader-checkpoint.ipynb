# %% [markdown]
# # Load pickle file containing SIFT keypoints and descriptors for each image

# %% [markdown]
# ### Necessary imports

# %%
import pickle
import glob
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

# %% [markdown]
# ### Load file

# %%
with open('SIFT_features.pkl', 'rb') as input_file:
    SIFT_features = pickle.load(input_file)

# %% [markdown]
# ### Pick a random image and get its keypoints and descriptors

# %%
# Get list of all images
img_paths = glob.glob('./Dataset/train/*')

# Draw an image randomly
i = np.random.randint(0, len(data))

# Obtain image path and name
img_path = img_paths[i]
img_name = img_path[16:-4]

# Load image
img = cv.cvtColor(cv.imread(img_path), cv.COLOR_BGR2RGB)

# Get keypoints and descriptors

# List for storing keypoint objects
kp = []

# Extract data for each keypoint from the image
for keypoint in SIFT_features[img_name]['keypoints']:
    point = keypoint['pt']
    size = keypoint['size']
    angle = keypoint['angle']
    response = keypoint['response']
    octave = keypoint['octave']
    class_id = keypoint['class_id']
    
    # Build keypoint object
    feature = cv.KeyPoint(x = point[0], y = point[1], _size = size, _angle = angle,
                         _response = response, _octave = octave, _class_id = class_id)
    
    # Append to keypoint list
    kp.append(feature)

des = SIFT_features[img_name]['descriptors']

# Show image and its SIFT features

# Draw features on image
kp_img = cv.drawKeypoints(img, kp, None, flags = cv.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

# Plot
plt.subplots(figsize = (15, 15))
plt.imshow(kp_img)
plt.axis('off')
plt.show()
